# %% [markdown]
# # Лабораторна робота №1
# ## Підсумкові функції та відображення
# * **Дисципліна**: Основи науки про дані
# * **Тема**: Підсумкові функції та відображення даних у Pandas
# * **Датасет**: Video Game Sales ([Kaggle](https://www.kaggle.com/datasets/gregorut/videogamesales))
# * **Виконав**: Осипенко Гліб Костянтинович
# * **Група**: ІМ-44

# %% [markdown]
# ### 1. Імпорт бібліотек
# Підключаємо pandas, numpy та бібліотеки для побудови графіків.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2. Завантаження датасету
# Читаємо файл `vgsales.csv` та дивимося перші рядки.

# %%
games = pd.read_csv('data/vgsales.csv')
games.head()
# Out:
#          Name Platform    Year     Genre   Publisher  NA_Sales  EU_Sales  \
# 0     Kaboom!     2600  1980.0      Misc  Activision      1.07      0.07
# 1      Boxing     2600  1980.0  Fighting  Activision      0.72      0.04
# 2  Ice Hockey     2600  1980.0    Sports  Activision      0.46      0.03
# 3     Freeway     2600  1980.0    Action  Activision      0.32      0.02
# 4      Bridge     2600  1980.0      Misc  Activision      0.25      0.02
#
#    JP_Sales  Other_Sales  Global_Sales
# 0       0.0         0.01          1.15
# 1       0.0         0.01          0.77
# 2       0.0         0.01          0.49
# 3       0.0         0.00          0.34
# 4       0.0         0.00          0.27

# %% [markdown]
# Перевіряємо загальну інформацію про датасет та типи стовпців.

# %%
games.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 16539 entries, 0 to 16538
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          16539 non-null  str
#  1   Platform      16539 non-null  str
#  2   Year          16290 non-null  float64
#  3   Genre         16539 non-null  str
#  4   Publisher     16539 non-null  str
#  5   NA_Sales      16539 non-null  float64
#  6   EU_Sales      16539 non-null  float64
#  7   JP_Sales      16539 non-null  float64
#  8   Other_Sales   16539 non-null  float64
#  9   Global_Sales  16539 non-null  float64
# dtypes: float64(6), str(4)
# memory usage: 1.3 MB

# %% [markdown]
# ### 3. Підсумкові функції (describe, unique, mean, value_counts)

# %% [markdown]
# Застосовуємо `describe()` для числового стовпця `Global_Sales` (світові продажі у млн копій).

# %%
# Огляд числового стовпця Global_Sales
games.Global_Sales.describe()
# Out:
# count    16539.000000
# mean         0.538441
# std          1.557470
# min          0.010000
# 25%          0.060000
# 50%          0.170000
# 75%          0.480000
# max         82.740000
# Name: Global_Sales, dtype: float64

# %% [markdown]
# Отримуємо унікальні числові значення для стовпця `Global_Sales`.

# %%
# Унікальні значення продажів
games.Global_Sales.unique()
# Out:
# array([1.150e+00, 7.700e-01, 4.900e-01, 3.400e-01, 2.700e-01, 4.310e+00,
#        2.760e+00, 1.050e+00, 2.400e-01, 7.900e-01, 2.200e-01, 4.500e+00,
#        1.600e+00, 1.100e+00, 4.800e-01, 4.300e-01, 3.900e-01, 1.970e+00,
#        1.650e+00, 1.360e+00, 9.700e-01, 7.300e-01, 5.000e-01, 4.500e-01,
#        2.600e-01, 2.100e-01, 1.300e-01, 1.460e+00, 5.900e-01, 4.000e-01,
#        2.130e+00, 1.270e+00, 3.700e-01, 6.700e-01, 3.600e-01, 3.100e-01,
#        1.900e-01, 1.700e-01, 8.200e-01, 2.200e+00, 9.300e-01, 3.300e-01,
#        6.900e-01, 2.900e-01, 2.500e-01, 6.600e-01, 5.500e-01, 1.500e-01,
#        7.810e+00, 1.640e+00, 1.590e+00, 1.180e+00, 1.120e+00, 1.080e+00,
#        7.800e-01, 7.200e-01, 6.200e-01, 3.800e-01, 1.400e-01, 5.400e-01,
#        3.200e-01, 5.800e-01, 8.700e-01, 2.800e-01, 6.300e-01, 1.310e+00,
#        4.600e-01, 3.200e+00, 2.280e+00, 2.140e+00, 1.130e+00, 1.110e+00,
#        1.520e+00, 1.220e+00, 2.831e+01, 4.160e+00, 4.010e+00, 2.170e+00,
# ...

# %% [markdown]
# Рахуємо середнє значення світових продажів.

# %%
# Середнє для Global_Sales
games.Global_Sales.mean()
# Out:
# np.float64(0.5384406554205212)

# %% [markdown]
# Дивимося список унікальних значень для категоріального стовпця `Genre` (жанри).

# %%
# Унікальні жанри ігор
games.Genre.unique()
# Out:
# <StringArray>
# [        'Misc',     'Fighting',       'Sports',       'Action',
#       'Shooter',     'Platform',       'Racing',       'Puzzle',
#    'Simulation',    'Adventure', 'Role-Playing',     'Strategy']
# Length: 12, dtype: str

# %% [markdown]
# Застосовуємо `describe()` до текстового стовпця `Genre`. Для категоріальних даних метод повертає count, unique, top (найчастіший жанр) та freq (його частоту).

# %%
# Огляд категоріального стовпця Genre
games.Genre.describe()
# Out:
# count      16539
# unique        12
# top       Action
# freq        3309
# Name: Genre, dtype: object

# %% [markdown]
# Підраховуємо кількість ігор для кожного жанру за допомогою `value_counts()`.

# %%
# Розподіл ігор за жанрами
games.Genre.value_counts()
# Out:
# Genre
# Action          3309
# Sports          2343
# Misc            1712
# Role-Playing    1486
# Shooter         1308
# Adventure       1282
# Racing          1248
# Platform         884
# Simulation       862
# Fighting         846
# Strategy         678
# Puzzle           581
# Name: count, dtype: int64

# %%
# Топ-10 платформ за кількістю випущених ігор
games.Platform.value_counts().head(10)
# Out:
# Platform
# PS2     2159
# DS      2155
# PS3     1326
# Wii     1324
# X360    1261
# PSP     1211
# PS      1193
# PC       954
# XB       824
# GBA      796
# Name: count, dtype: int64

# %% [markdown]
# ### 4. Відображення (map та apply)
# Використовуємо метод `map()` для перетворення одного стовпця, а `apply()` — для обробки рядків датафрейму.

# %% [markdown]
# Центруємо світові продажі відносно середнього значення за допомогою `map()`.

# %%
games_sales_mean = games.Global_Sales.mean()
games.Global_Sales.map(lambda s: s - games_sales_mean)
# Out:
# 0        0.611559
# 1        0.231559
# 2       -0.048441
# 3       -0.198441
# 4       -0.268441
#            ...
# 16534   -0.318441
# 16535   -0.418441
# 16536   -0.438441
# 16537   -0.438441
# 16538   -0.448441
# Name: Global_Sales, Length: 16539, dtype: float64

# %% [markdown]
# Створюємо функцію для рядка датафрейму: віднімаємо середнє від `Global_Sales` і додаємо новий стовпець `Revenue_Estimate` (орієнтовна виручка у млн $ при середній ціні $50 за гру).

# %%
def remean_sales(row):
    row.Global_Sales = row.Global_Sales - games_sales_mean
    row['Revenue_Estimate'] = (row.Global_Sales + games_sales_mean) * 50
    return row

games.apply(remean_sales, axis='columns')
# Out:
#                                Name Platform    Year     Genre  \
# 0                           Kaboom!     2600  1980.0      Misc
# 1                            Boxing     2600  1980.0  Fighting
# 2                        Ice Hockey     2600  1980.0    Sports
# 3                           Freeway     2600  1980.0    Action
# 4                            Bridge     2600  1980.0      Misc
# ...                             ...      ...     ...       ...
# 16534  LEGO Harry Potter: Years 5-7       PC     NaN    Action
# 16535                Happy Feet Two       DS     NaN    Action
# 16536                Happy Feet Two      PS3     NaN    Action
# 16537                Happy Feet Two     X360     NaN    Action
# 16538                Happy Feet Two      Wii     NaN    Action
#
#                                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0                                  Activision      1.07      0.07       0.0
# ...

# %% [markdown]
# Перевіряємо, що сам датафрейм `games` не змінився (методи `map` та `apply` повертають нові об'єкти, а не модифікують оригінал).

# %%
games.head()
# Out:
#          Name Platform    Year     Genre   Publisher  NA_Sales  EU_Sales  \
# 0     Kaboom!     2600  1980.0      Misc  Activision      1.07      0.07
# 1      Boxing     2600  1980.0  Fighting  Activision      0.72      0.04
# 2  Ice Hockey     2600  1980.0    Sports  Activision      0.46      0.03
# 3     Freeway     2600  1980.0    Action  Activision      0.32      0.02
# 4      Bridge     2600  1980.0      Misc  Activision      0.25      0.02
#
#    JP_Sales  Other_Sales  Global_Sales
# 0       0.0         0.01          1.15
# 1       0.0         0.01          0.77
# 2       0.0         0.01          0.49
# 3       0.0         0.00          0.34
# 4       0.0         0.00          0.27

# %% [markdown]
# ### 5. Вбудовані векторизовані операції
# Замінюємо метод `map()` прямою векторизованою операцією віднімання середнього значення.

# %%
games_sales_mean = games.Global_Sales.mean()
games.Global_Sales - games_sales_mean
# Out:
# 0        0.611559
# 1        0.231559
# 2       -0.048441
# 3       -0.198441
# 4       -0.268441
#            ...
# 16534   -0.318441
# 16535   -0.418441
# 16536   -0.438441
# 16537   -0.438441
# 16538   -0.448441
# Name: Global_Sales, Length: 16539, dtype: float64

# %% [markdown]
# Порівнюємо швидкість роботи методу `map()` та вбудованої векторизованої операції за допомогою `%timeit`.

# %%
# Замір часу для map
# %timeit games.Global_Sales.map(lambda s: s - games_sales_mean)
# Out:
# 2.05 ms ± 10.2 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Замір часу для векторизованої операції
# %timeit games.Global_Sales - games_sales_mean
# Out:
# 23.7 μs ± 869 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# Виконуємо векторизовані операції між двома стовпцями:
# 1. Конкатенація двох текстових стовпців (`Name` та `Platform`);
# 2. Додавання двох числових стовпців (`NA_Sales` та `EU_Sales`).

# %%
# Об'єднання назви гри та платформи
games.Name + " (" + games.Platform + ")"
# Out:
# 0                           Kaboom! (2600)
# 1                            Boxing (2600)
# 2                        Ice Hockey (2600)
# 3                           Freeway (2600)
# 4                            Bridge (2600)
#                        ...
# 16534    LEGO Harry Potter: Years 5-7 (PC)
# 16535                  Happy Feet Two (DS)
# 16536                 Happy Feet Two (PS3)
# 16537                Happy Feet Two (X360)
# 16538                 Happy Feet Two (Wii)
# Length: 16539, dtype: str

# %%
# Сумарні продажі в Північній Америці та Європі
games.NA_Sales + games.EU_Sales
# Out:
# 0        1.14
# 1        0.76
# 2        0.49
# 3        0.34
# 4        0.27
#          ...
# 16534    0.19
# 16535    0.11
# 16536    0.10
# 16537    0.09
# 16538    0.08
# Length: 16539, dtype: float64

# %% [markdown]
# ### 6. Візуалізація результатів для звіту

# %%
import os
os.makedirs('figures', exist_ok=True)

# 1. Розподіл кількості ігор за жанрами
plt.figure(figsize=(10, 5))
sns.countplot(data=games, y='Genre', order=games['Genre'].value_counts().index, hue='Genre', legend=False, palette='Blues_r')
plt.title('Розподіл відеоігор за жанрами')
plt.xlabel('Кількість ігор')
plt.ylabel('Жанр')
plt.grid(True, alpha=0.3)
plt.savefig('figures/genres.png', bbox_inches='tight')
plt.show()

# %%
# 2. Топ-10 найбільш продаваних ігор у світі
top10 = games.sort_values(by='Global_Sales', ascending=False).head(10)

plt.figure(figsize=(10, 5))
plt.barh(top10['Name'] + " (" + top10['Platform'] + ")", top10['Global_Sales'], color='steelblue')
plt.gca().invert_yaxis()
plt.title('Топ-10 найбільш продаваних відеоігор (світовий тираж)')
plt.xlabel('Глобальні продажі (млн копій)')
plt.ylabel('Гра')
plt.grid(True, alpha=0.3)
plt.savefig('figures/top10.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 7. Висновки
# У ході виконання лабораторної роботи:
# 1. Навчився працювати з основними підсумковими функціями Pandas: `describe()`, `mean()`, `unique()`, `value_counts()`. З'ясував, що для числових стовпців `describe()` розраховує середнє, стандартне відхилення, мінімум, максимум і квартилі, а для категоріальних — загальну кількість, кількість унікальних значень, моду (`top`) та її частоту (`freq`).
# 2. Застосував методи відображення `map()` (для одного стовпця) та `apply()` з `axis='columns'` (для построкової обробки датафрейму). На практиці перевірив, що ці методи повертають нові об'єкти і не змінюють вихідний датафрейм `games`.
# 3. Дослідив вбудовані векторизовані операції. Через магічну команду `%timeit` наочно побачив, що векторизоване віднімання скаляра працює в десятки разів швидше за `map()`, оскільки використовує оптимізовані C-масиви NumPy замість звичайного циклу Python.
# 4. Відпрацював операції над двома стовпцями: об'єднання текстових даних через конкатенацію `+` та поелементне додавання регіональних продажів.
